# %% [markdown]
# Mastering the chat completion API

# %% [markdown]
# Tha Anatomy of an API Endpoint

# %%
from typing import Dict, Any, List

def construct_chat_payload(model: str, user_message: str) -> Dict[str, Any]:
    return{
        "model": model,
        "messages": [
            {"role": "user",  "content": user_message}
        ]
    }

test_payload = construct_chat_payload("gpt-4o-mini", "Expalain in how many days Earth will be destroyed by the sun.")
print(f"Request Payload:\n {test_payload}")
# Out:
# Request Payload:
#  {'model': 'gpt-4o-mini', 'messages': [{'role': 'user', 'content': 'Expalain in how many days Earth will be destroyed by the sun.'}]}

# %%
import os
import requests
from dotenv import load_dotenv

env_loaded = load_dotenv(override=True)

def execute_raw_inference(payload: Dict[str, Any]) -> Dict[str, Any]:
    """
    Executes an inference request using the requests library (Raw HTTP).
    """
    api_url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {os.getenv('OPENAI_API_KEY')}",
        "Content-Type": "application/json"
    }
    
    response = requests.post(api_url, headers=headers, json=payload)
    return response.json()

raw_response = execute_raw_inference(test_payload)
#print(raw_response)
content = raw_response.get('choices', [{}])[0].get('message', {}).get('content')
print(f"Model Output:\n{content}")
# Out:
# Model Output:
# The Earth is not expected to be destroyed by the Sun for about 5 billion years. The Sun is currently a middle-aged star, and it is expected to continue in its stable phase for several billion more years before it enters the red giant phase.
#
# During the red giant phase, which is predicted to begin in about 5 billion years, the Sun will expand significantly, likely engulfing the inner planets, including Earth. This process will lead to the destruction of the planet as we know it.
#
# To estimate the number of days until then:
#
# 1. **5 billion years** = 5,000,000,000 years.
# 2. Convert years to days:
#    - 1 year = approximately 365.25 days (accounting for leap years).
#    - 5 billion years = 5,000,000,000 years * 365.25 days/year ≈ 1,826,000,000,000 days.
#
# So, the Earth has approximately **1.83 trillion days** left before it is likely to be destroyed by the Sun. Keep in mind that this estimate is based on current astronomical models, and many factors could influence this timeline, but it is safe to say that Earth is secure for billions of years to come.
