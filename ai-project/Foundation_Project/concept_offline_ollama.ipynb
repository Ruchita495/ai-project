# %% [markdown]
# Concept: The Offline Brain – Connecting the OpenAI SDK to Ollama
#
# In a production environment, you don't always need a massive, cloud-based model. Sometimes, the best architectural choice is a Small Language Model (SLM) running locally. This approach provides zero-cost inference, total privacy, and low-latency responses.
#
# In this lesson, we will explore how to use specialized SLMs for three distinct tasks: General Chat, Code Writing, and Data Analysis. We'll use the OpenAI SDK as our universal interface to keep our code clean and portable.
#
# 1. Professional Installation: The SLM Suite
# We are selecting models that are ultra-lightweight. These 'Precision SLMs' are designed to be extremely efficient while punching way above their weight class for specific tasks.
#
# Step-by-Step:
#
# Download Ollama: Visit ollama.com.
#
# Pull the Specialized SLMs:
#
# smollm:1.7b: Hugging Face's high-performance 1.7B
#
# model (Excellent for general chat).
#
# deepseek-coder:1.3b: A tiny but mighty coding
# specialist.
#
# qwen2:1.5b: A 1.5B parameter powerhouse for analysis and summarization.
#
# Open your terminal and run:
#
# ollama pull smollm:1.7b
#
# ollama pull deepseek-coder:1.3b
#
# ollama pull qwen2:1.5b

# %% [markdown]
# 2. The Multi-Model Switchboard
#
# Architect's Note: Notice how the base_url remains the same for every model. Ollama acts as a 'Local Model Gateway

# %%
from openai import OpenAI
from openai.types.shared import response_format_json_object

client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)

def query_local_llm(model, prompt, system_prompt="You are a helpful assistant."):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role":"system", "content": system_prompt},
                {"role":"user", "content": prompt}
            ],
            temperature=0.3
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error with {model}: {e}"

# %% [markdown]
# 3. Example 1: General Chat (SmolLM)
#
# Model: smollm:1.7b (1.7B) Use Case: Quick Q&A, brainstorming, and mobile-ready assistant tasks.

# %%
prompt = "Give me a simple 3-step guide to starting a fitness routine for a busy professional."
print(f"SmolLM (General Chat):\n{query_local_llm('smollm:1.7b', prompt)}")
# Out:
# SmolLM (General Chat):
# Here is a simple 3-step guide to starting a fitness routine for a busy professional:
#
# **Step 1: Set Realistic Goals**
#
# * Identify why you want to start a fitness routine (e.g. weight loss, increased energy, improved overall health).
# * Set specific, measurable, achievable, relevant, and time-bound (SMART) goals for your fitness routine (e.g. "I want to lose 10 pounds in 3 months and feel more energized during workdays").
# * Consider your schedule and priorities: what can you realistically fit into your daily routine?
#
# **Step 2: Choose an Exercise You Enjoy**
#
# * Think about the types of exercise you enjoy (e.g. running, swimming, cycling, yoga, weightlifting).
# * Consider what you can realistically fit into your schedule (e.g. 30 minutes of walking during lunch, 30 minutes of yoga in the morning).
# * Look for local gyms or fitness studios that offer classes or personal training that fit your schedule and preferences.
#
# **Step 3: Create a Schedule and Stick to It**
#
# * Schedule your workouts in your calendar and treat them as non-negotiable appointments.
# * Start with 2-3 times per week and gradually increase frequency as you become more comfortable with your routine.
# * Find a workout buddy or accountability partner to help you stay motivated and on track.
# * Be flexible and don't be too hard on yourself if you miss a workout. Simply get back on track as soon as possible.
#
# Additional Tips:
#
# * Start small and gradually increase intensity and duration as you become more comfortable with your routine.
# * Make sure to listen to your body and take rest days as needed.
# * Consider incorporating high-intensity interval training (HIIT) or other forms of active recovery (e.g. walking, stretching) into your routine to help you recover and reduce stress.
# * Look for ways to incorporate physical activity into your daily routine, such as taking the stairs instead of the elevator or going for a walk during your lunch break.
#
# By following these 3 steps, you can set yourself up for success and make a sustainable fitness routine that fits your busy schedule. Good luck!

# %% [markdown]
# 4. Example 2: Code Writing (DeepSeek Coder)
#
# Model: deepseek-coder:1.3b (1.3B) Use Case: Writing Python scripts, debugging, and explaining algorithms.
#
#
# DeepSeek Coder is optimized specifically for programming. Despite its tiny size, it understands syntax and logic remarkably well.

# %%
prompt = "Write a Python function to print 1 to 20 Table."
system = "You are an expert Python developer. Provide clean code with comments."
print(f"DeepSeek Coder (Programming):\n{query_local_llm('deepseek-coder:1.3b', prompt, system)}")
# Out:
# DeepSeek Coder (Programming):
# Sure, here is a simple Python function that prints a 1 to 20 multiplication table:
#
# ```python
# def multiplication_table(start, end):
#     for i in range(start, end+1):
#         for j in range(start, end+1):
#             print(f"{i} x {j} = {i*j}")
#         print("\n")
#
# multiplication_table(1, 20)
# ```
#
# This function takes two parameters: the start and end of the range for the multiplication table. It then uses two nested loops to print the multiplication table. The outer loop iterates over the rows, and the inner loop iterates over the columns. The result of the multiplication is printed in the format "x y = result". After each row is printed, a newline character is printed to separate the tables.

# %% [markdown]
# 5. Example 3: Data Analysis & Summarization (Qwen2)
#
# Model: qwen2:1.5b (1.5B) Use Case: Extracting key facts from long text and analyzing sentiment.
#
#
# Qwen2 is an extremely fast and precise model, perfect for 'skimming' through data to extract insights.

# %%
news_article = """
Tech Giant 'CyberCore' announced today a major breakthrough in quantum networking, 
claiming to have achieved stable entanglement over 100 kilometers of existing fiber optic cable. 
Industry experts suggest this could pave the way for a secure 'Quantum Internet' by 2030, 
though critics point to the massive cooling infrastructure required as a significant hurdle.
"""
prompt = f"Analyze this news snippet. Extract: 1. The main event, 2. The key timeline, and 3. The main challenge.\n\nArticle: {news_article}"
system = "You are a news analyst. Be concise and use bullet points."

print(f"Qwen2 (Analysis):\n{query_local_llm('qwen2:1.5b', prompt, system)}")
# Out:
# Qwen2 (Analysis):
# 1. Main Event: CyberCore's breakthrough in quantum networking
# 2. Key Timeline: Today
# 3. Main Challenge: The need for a massive cooling infrastructure
