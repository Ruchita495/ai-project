# %% [markdown]
# Python

# %%
import os
import sys
print("Python system info")
print(f"Version: {sys.version.split()[0]}")
print(f"Executable Path:{sys.executable}")
# Out:
# Python system info
# Version: 3.10.11
# Executable Path:C:\Users\pruch\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe

# %%
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("openai_api_key")
print(f"OpenAI API Detected: {'Yes' if openai_api_key else 'No'}")
# Out:
# OpenAI API Detected: Yes
